# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf

import pathlib
import os
import cv2 as cv

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

from skimage import exposure
import sys

import random
import shutil
import seaborn as sns

import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import regularizers

from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
# from tensorflow.keras.utils import np_utils
from sklearn import metrics
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras import regularizers
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore")
# tf.enable_eager_execution()

print(tf.__version__)
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 2.6.4

# %% [markdown]
# > **Load Dataset**

# %%
train_data = pathlib.Path('/kaggle/input/breast-moz/Dataset_BUSI/train')
test_data = pathlib.Path('/kaggle/input/breast-moz/Dataset_BUSI/test')
peso= pathlib.Path('/kaggle/working/')
print(train_data)
# Out:
# /kaggle/input/breast-moz/Dataset_BUSI/train

# %%
IMAGE_SIZE = 224

Nomes = ['Benign', 'Malign', 'Normal']
i0 = 0
i1 = 0
i2 = 0
i3 = 0

num_class = 3
batchsize = 32
epoch = 80
loss_function = "sparse_categorical_crossentropy"
optimizer = Adam(learning_rate=0.0001)
num_folds = 5


# container for metrics
acc_folds = []
f1_folds = []
prec_folds = []
recall_folds = []

# %%
def load_data(data_directory):
  
    directories = [d for d in os.listdir(data_directory)
                   if os.path.isdir(os.path.join(data_directory, d))]
    labels = []
    images = []
    file_names = []
    for d in directories:
        label_directory = os.path.join(data_directory, d)
        file_names += [os.path.join(label_directory, f)
                       for f in os.listdir(label_directory)]
                       
    random.shuffle(file_names)

    for f in file_names:
        #print(f)
        img = cv.imread(f)
        img = cv.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        dirname = os.path.split(os.path.dirname(f))[1]

        images.append(img)
        labels.append(int(dirname))

    images, labels = np.asarray(images), np.asarray(labels)
    images = images.astype('float32') / float(255)

    return images, labels

# %%
imagens, labels = load_data(train_data)

# %% [markdown]
# # **Data analizes**

# %%
imagens.shape
for x in range(0,5):
  plt.figure()
  plt.imshow(imagens[x])
  plt.show()

# %% [markdown]
# > **Split dataset**
#
# 1. A seguir o modelo eh treinado usando a tecnica de cross fold validation K-fold onde K=10.
# 2. O dataset eh devido em 10 subdataset e cada subdataset eh devido em traino e test
# 3. O desempenho em cada subdataset eh guardado
# 4. No final o desempenho final do modelo eh a media do desempenho em todos os 10 subdataset.
# 5. Depois calculamos o desvio padrao e o intervalo de confianca sobre o desempenho do nossso modelo.
#
# NB: O modelo abaixo usa

# %%
from tensorflow.keras.layers import BatchNormalization
kf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=29)
indice = 0

for train, test in kf.split(imagens, labels):
    imgs_train, imgs_val = imagens[train], imagens[test]
    labs_train, labs_val = labels[train], labels[test]
    
    print(imgs_train.shape)
    print(labs_train.shape)
    
#     model = keras.models.Sequential([
#     keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(IMAGE_SIZE, IMAGE_SIZE,3)),
#     keras.layers.BatchNormalization(),
#     keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
#     keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
#     keras.layers.BatchNormalization(),
#     keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
#     keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
#     keras.layers.BatchNormalization(),
#     keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
#     keras.layers.BatchNormalization(),
#     keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
#     keras.layers.BatchNormalization(),
#     keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
#     keras.layers.Flatten(),
#     keras.layers.Dense(4096, activation='relu'),
#     keras.layers.Dropout(0.5),
#     keras.layers.Dense(4096, activation='relu'),
#     keras.layers.Dropout(0.5),
#     keras.layers.Dense(10, activation='softmax')
# ])

    model = Sequential()

    model.add(Conv2D(input_shape=(IMAGE_SIZE, IMAGE_SIZE,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
#     model.add(BatchNormalization())
    model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(BatchNormalization())  
    model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
#     model.add(BatchNormalization())
    model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
#     model.add(BatchNormalization())
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
#     model.add(BatchNormalization())
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
    model.add(Flatten())

    model.add(Dense(units=4096,activation="relu"))
    model.add(BatchNormalization())
    model.add(Dense(units=4096,activation="relu"))
    model.add(BatchNormalization())
    model.add(Dense(num_class, activation="softmax"))
  
     
    #Compilar modelo

    # model.summary()
    model.compile(optimizer=optimizer, loss=loss_function, metrics=['accuracy'])
    xcept = model.fit(imgs_train, labs_train,batch_size=batchsize,validation_data=(imgs_val, labs_val), verbose=1,epochs=epoch)
    
    print(imgs_val.shape)
    print(labs_val.shape)

    labs_predict = model.predict(imgs_val)
    labs_predict = np.argmax(labs_predict, axis=1)

    accuracy = metrics.accuracy_score(labs_val, labs_predict)
    acc_folds.append(accuracy)

    f1 = metrics.f1_score(labs_val, labs_predict, average="macro")
    f1_folds.append(f1)

    precision = metrics.precision_score(labs_val, labs_predict, average="macro")
    prec_folds.append(precision)

    recall = metrics.recall_score(labs_val, labs_predict, average="macro")
    recall_folds.append(recall)

    print('Acurracy: %f' % accuracy)
    print('F1: %f' % f1)
    print('Precision: %f' % precision)
    print('Recall: %f' % recall)

    print("==========================================================================")
    plt.figure(0)
    plt.plot(xcept.history['accuracy'], 'r', label="train_acc")
    plt.plot(xcept.history['val_accuracy'], 'g', label="val_acc")
    plt.xlabel("Num of Epochs")
    plt.ylabel("Accuracy")
    plt.yscale('linear')
    plt.xscale('linear')
    plt.title("VGG16 Fold  \n \n"
                  "Training and Validation Accuracy")
    plt.tight_layout()
    plt.legend(loc='upper right')
    plt.grid(True, color='w', linestyle='-', linewidth=2)
    plt.gca().patch.set_facecolor('lightgrey')
    plt.legend()
    plt.savefig(str(peso) + '/VGG16Acc.png')
    plt.show()
    plt.close()

    plt.figure(1)
        
    plt.plot(xcept.history['loss'], 'b', label="train_loss")
    plt.plot(xcept.history['val_loss'], 'm', label="val_loss")
    plt.xlabel("Num of Epochs")
    plt.ylabel("Loss")
    plt.yscale('linear')
    plt.xscale('linear')
    plt.title("VGG  \n \n"
                  "Training and Validation Loss")
    plt.tight_layout()
    plt.legend(loc='upper right')
    plt.grid(True, color='w', linestyle='-', linewidth=2)
    plt.gca().patch.set_facecolor('lightgrey')
    plt.legend()
    plt.savefig(str(peso) + '/VGG16Loss.png')
    plt.show()
    
    hist_df = pd.DataFrame(xcept.history)
    hist_csv_file = '/kaggle/working/VGGhistory_' + str(indice) + '.csv'
    with open(hist_csv_file, mode='w') as f:
        hist_df.to_csv(f)
    
    indice += 1
    
    model = None
    imgs_train = None
    labs_train = None
    imgs_val = None
    labs_val = None


print("===================================================================")
print(f'> Global accuracy: {np.mean(acc_folds)} {np.std(acc_folds)}')
print(f'> Global F1_Score:  {np.mean(f1_folds)} {np.std(f1_folds)}')
print(f'> Global Precision: {np.mean(prec_folds)} {np.std(prec_folds)}')
print(f'> Global Recall:  {np.mean(recall_folds)} {np.std(recall_folds)}')
print("===================================================================")

print("Acuracia", acc_folds)
print("===================================================================")
print("F1 Score", f1_folds)
print("===================================================================")
print("Precision", prec_folds)
print("===================================================================")
print("Recall", recall_folds)
# Out:
# (504, 224, 224, 3)
# (504,)
# 2023-02-10 05:50:38.307127: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:38.308034: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:38.427560: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:38.428414: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:38.429247: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:38.430046: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:38.433285: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-10 05:50:38.665516: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:38.666401: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:38.667203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:38.667895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:38.668603: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:38.669298: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:41.430591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:41.431518: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:41.432274: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:41.433042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:41.433742: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:41.434404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2023-02-10 05:50:41.439610: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 05:50:41.440378: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 2023-02-10 05:50:42.835428: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/80
# 2023-02-10 05:50:45.865350: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 16/16 [==============================] - 41s 1s/step - loss: 1.9166 - accuracy: 0.5079 - val_loss: 1.4419 - val_accuracy: 0.1746
# Epoch 2/80
# 16/16 [==============================] - 8s 506ms/step - loss: 1.0545 - accuracy: 0.7520 - val_loss: 3.3003 - val_accuracy: 0.1746
# Epoch 3/80
# 16/16 [==============================] - 8s 512ms/step - loss: 0.8937 - accuracy: 0.7817 - val_loss: 3.7940 - val_accuracy: 0.1746
# Epoch 4/80
# 16/16 [==============================] - 8s 517ms/step - loss: 0.8372 - accuracy: 0.7956 - val_loss: 4.1393 - val_accuracy: 0.1746
# Epoch 5/80
# 16/16 [==============================] - 8s 524ms/step - loss: 0.6574 - accuracy: 0.8393 - val_loss: 6.0037 - val_accuracy: 0.1746
# Epoch 6/80
# 16/16 [==============================] - 9s 534ms/step - loss: 0.4962 - accuracy: 0.8810 - val_loss: 2.2424 - val_accuracy: 0.1746
# Epoch 7/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.4282 - accuracy: 0.8988 - val_loss: 1.9051 - val_accuracy: 0.1746
# Epoch 8/80
# 16/16 [==============================] - 9s 551ms/step - loss: 0.4373 - accuracy: 0.8948 - val_loss: 5.4869 - val_accuracy: 0.1746
# Epoch 9/80
# 16/16 [==============================] - 9s 560ms/step - loss: 0.3810 - accuracy: 0.9266 - val_loss: 5.3977 - val_accuracy: 0.1746
# Epoch 10/80
# 16/16 [==============================] - 9s 556ms/step - loss: 0.2034 - accuracy: 0.9425 - val_loss: 7.8047 - val_accuracy: 0.1746
# Epoch 11/80
# 16/16 [==============================] - 9s 548ms/step - loss: 0.1629 - accuracy: 0.9603 - val_loss: 13.0220 - val_accuracy: 0.1746
# Epoch 12/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.1143 - accuracy: 0.9702 - val_loss: 8.5268 - val_accuracy: 0.1746
# Epoch 13/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.1066 - accuracy: 0.9742 - val_loss: 7.4771 - val_accuracy: 0.1746
# Epoch 14/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.0652 - accuracy: 0.9861 - val_loss: 6.1532 - val_accuracy: 0.1746
# Epoch 15/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0426 - accuracy: 0.9921 - val_loss: 5.9889 - val_accuracy: 0.1746
# Epoch 16/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0878 - accuracy: 0.9881 - val_loss: 6.1077 - val_accuracy: 0.1746
# Epoch 17/80
# 16/16 [==============================] - 9s 544ms/step - loss: 0.0455 - accuracy: 0.9921 - val_loss: 6.3659 - val_accuracy: 0.1746
# Epoch 18/80
# 16/16 [==============================] - 9s 548ms/step - loss: 0.0562 - accuracy: 0.9861 - val_loss: 3.6084 - val_accuracy: 0.2619
# Epoch 19/80
# 16/16 [==============================] - 9s 552ms/step - loss: 0.1073 - accuracy: 0.9762 - val_loss: 4.3601 - val_accuracy: 0.1825
# Epoch 20/80
# 16/16 [==============================] - 9s 549ms/step - loss: 0.0971 - accuracy: 0.9881 - val_loss: 5.0301 - val_accuracy: 0.2222
# Epoch 21/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.0642 - accuracy: 0.9762 - val_loss: 8.3559 - val_accuracy: 0.2619
# Epoch 22/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.1108 - accuracy: 0.9762 - val_loss: 7.8767 - val_accuracy: 0.1905
# Epoch 23/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.1227 - accuracy: 0.9702 - val_loss: 4.7666 - val_accuracy: 0.2778
# Epoch 24/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0692 - accuracy: 0.9841 - val_loss: 5.5626 - val_accuracy: 0.2698
# Epoch 25/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0743 - accuracy: 0.9742 - val_loss: 17.8637 - val_accuracy: 0.2619
# Epoch 26/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.2115 - accuracy: 0.9583 - val_loss: 4.4926 - val_accuracy: 0.5635
# Epoch 27/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.1654 - accuracy: 0.9782 - val_loss: 4.2953 - val_accuracy: 0.4127
# Epoch 28/80
# 16/16 [==============================] - 9s 549ms/step - loss: 0.0972 - accuracy: 0.9782 - val_loss: 9.5583 - val_accuracy: 0.3889
# Epoch 29/80
# 16/16 [==============================] - 9s 549ms/step - loss: 0.1562 - accuracy: 0.9702 - val_loss: 8.4192 - val_accuracy: 0.2857
# Epoch 30/80
# 16/16 [==============================] - 9s 549ms/step - loss: 0.0904 - accuracy: 0.9861 - val_loss: 3.3398 - val_accuracy: 0.4841
# Epoch 31/80
# 16/16 [==============================] - 9s 545ms/step - loss: 0.0648 - accuracy: 0.9802 - val_loss: 5.2488 - val_accuracy: 0.3016
# Epoch 32/80
# 16/16 [==============================] - 9s 544ms/step - loss: 0.0985 - accuracy: 0.9762 - val_loss: 5.6709 - val_accuracy: 0.3651
# Epoch 33/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0776 - accuracy: 0.9802 - val_loss: 8.6040 - val_accuracy: 0.2857
# Epoch 34/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0722 - accuracy: 0.9802 - val_loss: 3.7406 - val_accuracy: 0.4683
# Epoch 35/80
# 16/16 [==============================] - 9s 544ms/step - loss: 0.0778 - accuracy: 0.9861 - val_loss: 4.0876 - val_accuracy: 0.5000
# Epoch 36/80
# 16/16 [==============================] - 9s 544ms/step - loss: 0.0691 - accuracy: 0.9841 - val_loss: 3.0607 - val_accuracy: 0.6032
# Epoch 37/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.0828 - accuracy: 0.9802 - val_loss: 4.3270 - val_accuracy: 0.5397
# Epoch 38/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.0574 - accuracy: 0.9802 - val_loss: 4.1305 - val_accuracy: 0.5079
# Epoch 39/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.0373 - accuracy: 0.9901 - val_loss: 1.9741 - val_accuracy: 0.6270
# Epoch 40/80
# 16/16 [==============================] - 9s 549ms/step - loss: 0.0644 - accuracy: 0.9841 - val_loss: 3.7053 - val_accuracy: 0.6270
# Epoch 41/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.0965 - accuracy: 0.9901 - val_loss: 2.3411 - val_accuracy: 0.6984
# Epoch 42/80
# 16/16 [==============================] - 9s 549ms/step - loss: 0.0784 - accuracy: 0.9802 - val_loss: 1.9115 - val_accuracy: 0.7302
# Epoch 43/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.1442 - accuracy: 0.9702 - val_loss: 1.7408 - val_accuracy: 0.7143
# Epoch 44/80
# 16/16 [==============================] - 9s 550ms/step - loss: 0.0781 - accuracy: 0.9802 - val_loss: 2.5950 - val_accuracy: 0.6508
# Epoch 45/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.1325 - accuracy: 0.9762 - val_loss: 1.5936 - val_accuracy: 0.7540
# Epoch 46/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.1173 - accuracy: 0.9702 - val_loss: 1.7015 - val_accuracy: 0.7143
# Epoch 47/80
# 16/16 [==============================] - 9s 545ms/step - loss: 0.1085 - accuracy: 0.9683 - val_loss: 2.2724 - val_accuracy: 0.6746
# Epoch 48/80
# 16/16 [==============================] - 9s 548ms/step - loss: 0.1495 - accuracy: 0.9623 - val_loss: 2.0004 - val_accuracy: 0.7460
# Epoch 49/80
# 16/16 [==============================] - 9s 545ms/step - loss: 0.2158 - accuracy: 0.9524 - val_loss: 2.2513 - val_accuracy: 0.7381
# Epoch 50/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.1626 - accuracy: 0.9583 - val_loss: 1.2652 - val_accuracy: 0.7778
# Epoch 51/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.1113 - accuracy: 0.9762 - val_loss: 2.7567 - val_accuracy: 0.6111
# Epoch 52/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.0479 - accuracy: 0.9881 - val_loss: 1.2781 - val_accuracy: 0.7619
# Epoch 53/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.0893 - accuracy: 0.9802 - val_loss: 1.2518 - val_accuracy: 0.7222
# Epoch 54/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.0701 - accuracy: 0.9782 - val_loss: 1.1719 - val_accuracy: 0.8095
# Epoch 55/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.0637 - accuracy: 0.9921 - val_loss: 1.3696 - val_accuracy: 0.7698
# Epoch 56/80
# 16/16 [==============================] - 9s 545ms/step - loss: 0.0705 - accuracy: 0.9841 - val_loss: 1.3272 - val_accuracy: 0.8254
# Epoch 57/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.0504 - accuracy: 0.9841 - val_loss: 1.4072 - val_accuracy: 0.7937
# Epoch 58/80
# 16/16 [==============================] - 9s 549ms/step - loss: 0.0591 - accuracy: 0.9861 - val_loss: 1.1289 - val_accuracy: 0.7937
# Epoch 59/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.1931 - accuracy: 0.9762 - val_loss: 1.2896 - val_accuracy: 0.7937
# Epoch 60/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.0473 - accuracy: 0.9861 - val_loss: 1.2741 - val_accuracy: 0.7937
# Epoch 61/80
# 16/16 [==============================] - 9s 548ms/step - loss: 0.0692 - accuracy: 0.9841 - val_loss: 1.4288 - val_accuracy: 0.8095
# Epoch 62/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.0545 - accuracy: 0.9821 - val_loss: 1.4198 - val_accuracy: 0.8254
# Epoch 63/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 1.5841 - val_accuracy: 0.7857
# Epoch 64/80
# 16/16 [==============================] - 9s 545ms/step - loss: 0.0401 - accuracy: 0.9901 - val_loss: 1.6243 - val_accuracy: 0.8095
# Epoch 65/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.0539 - accuracy: 0.9861 - val_loss: 1.4980 - val_accuracy: 0.7937
# Epoch 66/80
# 16/16 [==============================] - 9s 545ms/step - loss: 0.0707 - accuracy: 0.9921 - val_loss: 1.5008 - val_accuracy: 0.7937
# Epoch 67/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.0746 - accuracy: 0.9881 - val_loss: 1.7471 - val_accuracy: 0.8175
# Epoch 68/80
# 16/16 [==============================] - 9s 545ms/step - loss: 0.0433 - accuracy: 0.9881 - val_loss: 1.6450 - val_accuracy: 0.8254
# Epoch 69/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.0190 - accuracy: 0.9921 - val_loss: 1.2759 - val_accuracy: 0.8254
# Epoch 70/80
# 16/16 [==============================] - 9s 544ms/step - loss: 0.0243 - accuracy: 0.9921 - val_loss: 1.3745 - val_accuracy: 0.8333
# Epoch 71/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.0051 - accuracy: 0.9980 - val_loss: 1.4170 - val_accuracy: 0.8254
# Epoch 72/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 1.3818 - val_accuracy: 0.8254
# Epoch 73/80
# 16/16 [==============================] - 9s 548ms/step - loss: 0.0160 - accuracy: 0.9980 - val_loss: 1.2553 - val_accuracy: 0.8333
# Epoch 74/80
# 16/16 [==============================] - 9s 545ms/step - loss: 0.0101 - accuracy: 0.9960 - val_loss: 1.2632 - val_accuracy: 0.8333
# Epoch 75/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 1.2500 - val_accuracy: 0.8333
# Epoch 76/80
# 16/16 [==============================] - 9s 549ms/step - loss: 0.0251 - accuracy: 0.9960 - val_loss: 1.2427 - val_accuracy: 0.8254
# Epoch 77/80
# 16/16 [==============================] - 9s 548ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 1.5331 - val_accuracy: 0.8095
# Epoch 78/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.0164 - accuracy: 0.9960 - val_loss: 1.4880 - val_accuracy: 0.8095
# Epoch 79/80
# 16/16 [==============================] - 9s 547ms/step - loss: 0.0141 - accuracy: 0.9940 - val_loss: 1.5176 - val_accuracy: 0.7857
# Epoch 80/80
# 16/16 [==============================] - 9s 546ms/step - loss: 0.0268 - accuracy: 0.9980 - val_loss: 1.4201 - val_accuracy: 0.8095
# (126, 224, 224, 3)
# (126,)
# Acurracy: 0.809524
# F1: 0.775842
# Precision: 0.805164
# Recall: 0.755015
# ==========================================================================
# (504, 224, 224, 3)
# (504,)
# Epoch 1/80
# 16/16 [==============================] - 11s 582ms/step - loss: 4.8866 - accuracy: 0.4583 - val_loss: 4.9750 - val_accuracy: 0.2540
# Epoch 2/80
# 16/16 [==============================] - 9s 539ms/step - loss: 2.2508 - accuracy: 0.5496 - val_loss: 29.5121 - val_accuracy: 0.2619
# Epoch 3/80
# 16/16 [==============================] - 9s 541ms/step - loss: 1.5246 - accuracy: 0.6290 - val_loss: 6.0590 - val_accuracy: 0.2619
# Epoch 4/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.7192 - accuracy: 0.7242 - val_loss: 7.0859 - val_accuracy: 0.2619
# Epoch 5/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.5020 - accuracy: 0.8016 - val_loss: 7.2106 - val_accuracy: 0.2619
# Epoch 6/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.3676 - accuracy: 0.8770 - val_loss: 9.1399 - val_accuracy: 0.2619
# Epoch 7/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.2535 - accuracy: 0.9107 - val_loss: 5.9109 - val_accuracy: 0.2619
# Epoch 8/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.1562 - accuracy: 0.9464 - val_loss: 3.5687 - val_accuracy: 0.2619
# Epoch 9/80
# 16/16 [==============================] - 9s 536ms/step - loss: 0.1441 - accuracy: 0.9563 - val_loss: 4.9472 - val_accuracy: 0.2619
# Epoch 10/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.1004 - accuracy: 0.9722 - val_loss: 6.8334 - val_accuracy: 0.2619
# Epoch 11/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.1089 - accuracy: 0.9683 - val_loss: 6.2204 - val_accuracy: 0.2619
# Epoch 12/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0837 - accuracy: 0.9802 - val_loss: 8.1377 - val_accuracy: 0.2619
# Epoch 13/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.1055 - accuracy: 0.9643 - val_loss: 8.7878 - val_accuracy: 0.2619
# Epoch 14/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0882 - accuracy: 0.9762 - val_loss: 5.0767 - val_accuracy: 0.2619
# Epoch 15/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0660 - accuracy: 0.9802 - val_loss: 8.3176 - val_accuracy: 0.2619
# Epoch 16/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0698 - accuracy: 0.9841 - val_loss: 5.8927 - val_accuracy: 0.2619
# Epoch 17/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0663 - accuracy: 0.9841 - val_loss: 6.8755 - val_accuracy: 0.2619
# Epoch 18/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0472 - accuracy: 0.9821 - val_loss: 6.4684 - val_accuracy: 0.2619
# Epoch 19/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0691 - accuracy: 0.9821 - val_loss: 7.3034 - val_accuracy: 0.2619
# Epoch 20/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0797 - accuracy: 0.9821 - val_loss: 6.3879 - val_accuracy: 0.2619
# Epoch 21/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0508 - accuracy: 0.9841 - val_loss: 8.9787 - val_accuracy: 0.2619
# Epoch 22/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0501 - accuracy: 0.9881 - val_loss: 4.7349 - val_accuracy: 0.2778
# Epoch 23/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0788 - accuracy: 0.9762 - val_loss: 5.5787 - val_accuracy: 0.2937
# Epoch 24/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0653 - accuracy: 0.9841 - val_loss: 6.9785 - val_accuracy: 0.2778
# Epoch 25/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0343 - accuracy: 0.9881 - val_loss: 3.7008 - val_accuracy: 0.3333
# Epoch 26/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0426 - accuracy: 0.9901 - val_loss: 2.8509 - val_accuracy: 0.4048
# Epoch 27/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0466 - accuracy: 0.9821 - val_loss: 5.9005 - val_accuracy: 0.2698
# Epoch 28/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0388 - accuracy: 0.9861 - val_loss: 5.0283 - val_accuracy: 0.2937
# Epoch 29/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0852 - accuracy: 0.9702 - val_loss: 2.1729 - val_accuracy: 0.4841
# Epoch 30/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0700 - accuracy: 0.9802 - val_loss: 1.7279 - val_accuracy: 0.6349
# Epoch 31/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0697 - accuracy: 0.9782 - val_loss: 1.8101 - val_accuracy: 0.6429
# Epoch 32/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0513 - accuracy: 0.9881 - val_loss: 1.8812 - val_accuracy: 0.5000
# Epoch 33/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0569 - accuracy: 0.9861 - val_loss: 2.0132 - val_accuracy: 0.5079
# Epoch 34/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0471 - accuracy: 0.9881 - val_loss: 1.7275 - val_accuracy: 0.6349
# Epoch 35/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0426 - accuracy: 0.9841 - val_loss: 1.7343 - val_accuracy: 0.6349
# Epoch 36/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0687 - accuracy: 0.9821 - val_loss: 1.3847 - val_accuracy: 0.6587
# Epoch 37/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0587 - accuracy: 0.9802 - val_loss: 1.5140 - val_accuracy: 0.5714
# Epoch 38/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0510 - accuracy: 0.9841 - val_loss: 1.4190 - val_accuracy: 0.6349
# Epoch 39/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0789 - accuracy: 0.9802 - val_loss: 1.5561 - val_accuracy: 0.6508
# Epoch 40/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0240 - accuracy: 0.9940 - val_loss: 1.4648 - val_accuracy: 0.6667
# Epoch 41/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0359 - accuracy: 0.9901 - val_loss: 1.2456 - val_accuracy: 0.7222
# Epoch 42/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0213 - accuracy: 0.9921 - val_loss: 1.1295 - val_accuracy: 0.7381
# Epoch 43/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0337 - accuracy: 0.9940 - val_loss: 1.1336 - val_accuracy: 0.7540
# Epoch 44/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0607 - accuracy: 0.9881 - val_loss: 1.1642 - val_accuracy: 0.7381
# Epoch 45/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0314 - accuracy: 0.9901 - val_loss: 0.8550 - val_accuracy: 0.8413
# Epoch 46/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0293 - accuracy: 0.9940 - val_loss: 0.8974 - val_accuracy: 0.7778
# Epoch 47/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0323 - accuracy: 0.9881 - val_loss: 0.9449 - val_accuracy: 0.8175
# Epoch 48/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0311 - accuracy: 0.9901 - val_loss: 1.1316 - val_accuracy: 0.7698
# Epoch 49/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0460 - accuracy: 0.9921 - val_loss: 1.0849 - val_accuracy: 0.7619
# Epoch 50/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0246 - accuracy: 0.9960 - val_loss: 0.9282 - val_accuracy: 0.8254
# Epoch 51/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0207 - accuracy: 0.9940 - val_loss: 0.9025 - val_accuracy: 0.8095
# Epoch 52/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0421 - accuracy: 0.9901 - val_loss: 1.0079 - val_accuracy: 0.8175
# Epoch 53/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 0.9515 - val_accuracy: 0.8333
# Epoch 54/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0284 - accuracy: 0.9901 - val_loss: 0.8967 - val_accuracy: 0.8492
# Epoch 55/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0252 - accuracy: 0.9901 - val_loss: 0.9865 - val_accuracy: 0.8413
# Epoch 56/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0216 - accuracy: 0.9921 - val_loss: 1.0223 - val_accuracy: 0.8175
# Epoch 57/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0248 - accuracy: 0.9980 - val_loss: 1.0678 - val_accuracy: 0.8175
# Epoch 58/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0218 - accuracy: 0.9921 - val_loss: 0.8705 - val_accuracy: 0.8175
# Epoch 59/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0197 - accuracy: 0.9921 - val_loss: 0.8643 - val_accuracy: 0.7857
# Epoch 60/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0669 - accuracy: 0.9881 - val_loss: 0.9493 - val_accuracy: 0.8016
# Epoch 61/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0179 - accuracy: 0.9921 - val_loss: 0.8407 - val_accuracy: 0.8413
# Epoch 62/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0145 - accuracy: 0.9960 - val_loss: 0.9093 - val_accuracy: 0.8254
# Epoch 63/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0275 - accuracy: 0.9940 - val_loss: 1.1530 - val_accuracy: 0.8254
# Epoch 64/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0250 - accuracy: 0.9940 - val_loss: 1.0700 - val_accuracy: 0.8175
# Epoch 65/80
# 16/16 [==============================] - 9s 544ms/step - loss: 0.0153 - accuracy: 0.9960 - val_loss: 0.9283 - val_accuracy: 0.8254
# Epoch 66/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.7934 - val_accuracy: 0.8175
# Epoch 67/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0146 - accuracy: 0.9901 - val_loss: 0.9267 - val_accuracy: 0.8175
# Epoch 68/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0234 - accuracy: 0.9940 - val_loss: 0.9710 - val_accuracy: 0.7778
# Epoch 69/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0415 - accuracy: 0.9881 - val_loss: 0.9384 - val_accuracy: 0.8175
# Epoch 70/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0103 - accuracy: 0.9960 - val_loss: 0.9191 - val_accuracy: 0.8254
# Epoch 71/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0372 - accuracy: 0.9881 - val_loss: 1.0009 - val_accuracy: 0.8016
# Epoch 72/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0286 - accuracy: 0.9901 - val_loss: 1.0139 - val_accuracy: 0.8095
# Epoch 73/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0194 - accuracy: 0.9940 - val_loss: 0.8965 - val_accuracy: 0.8016
# Epoch 74/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0220 - accuracy: 0.9921 - val_loss: 0.9368 - val_accuracy: 0.8016
# Epoch 75/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0257 - accuracy: 0.9921 - val_loss: 0.7902 - val_accuracy: 0.8016
# Epoch 76/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0494 - accuracy: 0.9921 - val_loss: 0.7665 - val_accuracy: 0.7857
# Epoch 77/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0393 - accuracy: 0.9940 - val_loss: 0.7352 - val_accuracy: 0.8492
# Epoch 78/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0138 - accuracy: 0.9940 - val_loss: 0.8827 - val_accuracy: 0.8175
# Epoch 79/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0776 - accuracy: 0.9861 - val_loss: 0.8417 - val_accuracy: 0.8175
# Epoch 80/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.1325 - accuracy: 0.9742 - val_loss: 1.0071 - val_accuracy: 0.8333
# (126, 224, 224, 3)
# (126,)
# Acurracy: 0.833333
# F1: 0.808231
# Precision: 0.813526
# Recall: 0.805520
# ==========================================================================
# (504, 224, 224, 3)
# (504,)
# Epoch 1/80
# 16/16 [==============================] - 11s 568ms/step - loss: 4.6484 - accuracy: 0.4802 - val_loss: 3.3997 - val_accuracy: 0.1746
# Epoch 2/80
# 16/16 [==============================] - 9s 539ms/step - loss: 1.9134 - accuracy: 0.5377 - val_loss: 9.0625 - val_accuracy: 0.2619
# Epoch 3/80
# 16/16 [==============================] - 9s 541ms/step - loss: 1.2256 - accuracy: 0.6171 - val_loss: 44.1001 - val_accuracy: 0.2698
# Epoch 4/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.7270 - accuracy: 0.7381 - val_loss: 11.2379 - val_accuracy: 0.2302
# Epoch 5/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.5276 - accuracy: 0.8016 - val_loss: 6.1203 - val_accuracy: 0.2698
# Epoch 6/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.3893 - accuracy: 0.8472 - val_loss: 6.8015 - val_accuracy: 0.2698
# Epoch 7/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.3629 - accuracy: 0.8651 - val_loss: 10.6241 - val_accuracy: 0.2698
# Epoch 8/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.3071 - accuracy: 0.8869 - val_loss: 10.2444 - val_accuracy: 0.2698
# Epoch 9/80
# 16/16 [==============================] - 9s 536ms/step - loss: 0.2904 - accuracy: 0.9107 - val_loss: 5.7901 - val_accuracy: 0.2698
# Epoch 10/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.2234 - accuracy: 0.9246 - val_loss: 10.5107 - val_accuracy: 0.2698
# Epoch 11/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.2048 - accuracy: 0.9266 - val_loss: 7.3083 - val_accuracy: 0.2698
# Epoch 12/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.1981 - accuracy: 0.9464 - val_loss: 5.1410 - val_accuracy: 0.2778
# Epoch 13/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.1407 - accuracy: 0.9524 - val_loss: 6.5540 - val_accuracy: 0.2698
# Epoch 14/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.1306 - accuracy: 0.9504 - val_loss: 4.6027 - val_accuracy: 0.2778
# Epoch 15/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0744 - accuracy: 0.9782 - val_loss: 4.7196 - val_accuracy: 0.2857
# Epoch 16/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.1161 - accuracy: 0.9623 - val_loss: 4.3660 - val_accuracy: 0.2698
# Epoch 17/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.1264 - accuracy: 0.9663 - val_loss: 3.2811 - val_accuracy: 0.3889
# Epoch 18/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.1033 - accuracy: 0.9782 - val_loss: 4.8137 - val_accuracy: 0.3492
# Epoch 19/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0610 - accuracy: 0.9861 - val_loss: 5.1072 - val_accuracy: 0.3492
# Epoch 20/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.1113 - accuracy: 0.9722 - val_loss: 3.7436 - val_accuracy: 0.4048
# Epoch 21/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0746 - accuracy: 0.9762 - val_loss: 5.6715 - val_accuracy: 0.2857
# Epoch 22/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0486 - accuracy: 0.9841 - val_loss: 4.4377 - val_accuracy: 0.3889
# Epoch 23/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0731 - accuracy: 0.9802 - val_loss: 5.1140 - val_accuracy: 0.3810
# Epoch 24/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0713 - accuracy: 0.9841 - val_loss: 5.6836 - val_accuracy: 0.3730
# Epoch 25/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0759 - accuracy: 0.9762 - val_loss: 3.0839 - val_accuracy: 0.3730
# Epoch 26/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0764 - accuracy: 0.9821 - val_loss: 7.8547 - val_accuracy: 0.3413
# Epoch 27/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0523 - accuracy: 0.9821 - val_loss: 6.8805 - val_accuracy: 0.3571
# Epoch 28/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0530 - accuracy: 0.9881 - val_loss: 7.4386 - val_accuracy: 0.3175
# Epoch 29/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0649 - accuracy: 0.9782 - val_loss: 6.0641 - val_accuracy: 0.3651
# Epoch 30/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0477 - accuracy: 0.9861 - val_loss: 4.6921 - val_accuracy: 0.4365
# Epoch 31/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0580 - accuracy: 0.9841 - val_loss: 3.9008 - val_accuracy: 0.4206
# Epoch 32/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0567 - accuracy: 0.9782 - val_loss: 4.5876 - val_accuracy: 0.4127
# Epoch 33/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0870 - accuracy: 0.9821 - val_loss: 5.8363 - val_accuracy: 0.3175
# Epoch 34/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0510 - accuracy: 0.9861 - val_loss: 5.0697 - val_accuracy: 0.3810
# Epoch 35/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0649 - accuracy: 0.9802 - val_loss: 3.2149 - val_accuracy: 0.4921
# Epoch 36/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0443 - accuracy: 0.9960 - val_loss: 2.9911 - val_accuracy: 0.4921
# Epoch 37/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 2.7039 - val_accuracy: 0.5000
# Epoch 38/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0522 - accuracy: 0.9861 - val_loss: 2.2649 - val_accuracy: 0.5635
# Epoch 39/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0406 - accuracy: 0.9861 - val_loss: 2.1492 - val_accuracy: 0.5476
# Epoch 40/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0324 - accuracy: 0.9921 - val_loss: 1.7824 - val_accuracy: 0.5714
# Epoch 41/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0292 - accuracy: 0.9960 - val_loss: 1.7535 - val_accuracy: 0.6270
# Epoch 42/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0447 - accuracy: 0.9901 - val_loss: 1.5155 - val_accuracy: 0.6587
# Epoch 43/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0572 - accuracy: 0.9921 - val_loss: 1.6631 - val_accuracy: 0.6349
# Epoch 44/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0621 - accuracy: 0.9841 - val_loss: 1.2894 - val_accuracy: 0.7381
# Epoch 45/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0594 - accuracy: 0.9881 - val_loss: 1.1498 - val_accuracy: 0.7143
# Epoch 46/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0343 - accuracy: 0.9881 - val_loss: 1.1392 - val_accuracy: 0.7222
# Epoch 47/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0315 - accuracy: 0.9881 - val_loss: 1.4562 - val_accuracy: 0.6429
# Epoch 48/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0523 - accuracy: 0.9861 - val_loss: 1.1344 - val_accuracy: 0.7143
# Epoch 49/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0328 - accuracy: 0.9901 - val_loss: 1.3436 - val_accuracy: 0.7302
# Epoch 50/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0518 - accuracy: 0.9881 - val_loss: 1.4205 - val_accuracy: 0.7063
# Epoch 51/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0186 - accuracy: 0.9901 - val_loss: 2.2211 - val_accuracy: 0.6270
# Epoch 52/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0375 - accuracy: 0.9881 - val_loss: 1.4917 - val_accuracy: 0.7460
# Epoch 53/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0478 - accuracy: 0.9881 - val_loss: 1.3777 - val_accuracy: 0.7222
# Epoch 54/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0443 - accuracy: 0.9881 - val_loss: 1.6250 - val_accuracy: 0.7381
# Epoch 55/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0633 - accuracy: 0.9881 - val_loss: 1.6392 - val_accuracy: 0.7460
# Epoch 56/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0635 - accuracy: 0.9841 - val_loss: 1.3119 - val_accuracy: 0.7540
# Epoch 57/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0606 - accuracy: 0.9802 - val_loss: 1.3888 - val_accuracy: 0.7778
# Epoch 58/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0226 - accuracy: 0.9921 - val_loss: 1.1869 - val_accuracy: 0.8016
# Epoch 59/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0246 - accuracy: 0.9901 - val_loss: 1.3345 - val_accuracy: 0.7619
# Epoch 60/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0464 - accuracy: 0.9881 - val_loss: 1.1756 - val_accuracy: 0.7698
# Epoch 61/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0356 - accuracy: 0.9921 - val_loss: 1.3313 - val_accuracy: 0.7460
# Epoch 62/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0452 - accuracy: 0.9921 - val_loss: 1.1425 - val_accuracy: 0.8254
# Epoch 63/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0306 - accuracy: 0.9901 - val_loss: 1.2268 - val_accuracy: 0.8016
# Epoch 64/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0357 - accuracy: 0.9921 - val_loss: 1.3567 - val_accuracy: 0.7857
# Epoch 65/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0406 - accuracy: 0.9881 - val_loss: 1.1215 - val_accuracy: 0.7698
# Epoch 66/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0404 - accuracy: 0.9841 - val_loss: 1.1836 - val_accuracy: 0.7698
# Epoch 67/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0408 - accuracy: 0.9901 - val_loss: 1.2335 - val_accuracy: 0.7937
# Epoch 68/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0872 - accuracy: 0.9802 - val_loss: 1.4139 - val_accuracy: 0.7381
# Epoch 69/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0486 - accuracy: 0.9821 - val_loss: 1.2571 - val_accuracy: 0.7937
# Epoch 70/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0482 - accuracy: 0.9861 - val_loss: 1.2433 - val_accuracy: 0.7619
# Epoch 71/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0727 - accuracy: 0.9802 - val_loss: 1.4449 - val_accuracy: 0.7698
# Epoch 72/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.1131 - accuracy: 0.9722 - val_loss: 1.6189 - val_accuracy: 0.7381
# Epoch 73/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.1118 - accuracy: 0.9742 - val_loss: 2.4503 - val_accuracy: 0.5873
# Epoch 74/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0750 - accuracy: 0.9742 - val_loss: 1.7442 - val_accuracy: 0.7460
# Epoch 75/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.1022 - accuracy: 0.9683 - val_loss: 1.4764 - val_accuracy: 0.7619
# Epoch 76/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.1003 - accuracy: 0.9683 - val_loss: 1.9939 - val_accuracy: 0.6587
# Epoch 77/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0753 - accuracy: 0.9782 - val_loss: 1.5714 - val_accuracy: 0.7619
# Epoch 78/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0773 - accuracy: 0.9841 - val_loss: 1.5048 - val_accuracy: 0.7460
# Epoch 79/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0868 - accuracy: 0.9821 - val_loss: 1.5399 - val_accuracy: 0.7222
# Epoch 80/80
# 16/16 [==============================] - 9s 544ms/step - loss: 0.0920 - accuracy: 0.9603 - val_loss: 1.4787 - val_accuracy: 0.7698
# (126, 224, 224, 3)
# (126,)
# Acurracy: 0.769841
# F1: 0.733969
# Precision: 0.735316
# Recall: 0.754800
# ==========================================================================
# (504, 224, 224, 3)
# (504,)
# Epoch 1/80
# 16/16 [==============================] - 11s 567ms/step - loss: 5.4436 - accuracy: 0.4821 - val_loss: 15.1829 - val_accuracy: 0.2698
# Epoch 2/80
# 16/16 [==============================] - 9s 539ms/step - loss: 2.4959 - accuracy: 0.5456 - val_loss: 10.4732 - val_accuracy: 0.5556
# Epoch 3/80
# 16/16 [==============================] - 9s 542ms/step - loss: 1.5683 - accuracy: 0.5833 - val_loss: 18.0612 - val_accuracy: 0.2698
# Epoch 4/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.8202 - accuracy: 0.7103 - val_loss: 9.0219 - val_accuracy: 0.5556
# Epoch 5/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.5749 - accuracy: 0.7817 - val_loss: 11.9055 - val_accuracy: 0.2698
# Epoch 6/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.4397 - accuracy: 0.8313 - val_loss: 16.8485 - val_accuracy: 0.2698
# Epoch 7/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.3012 - accuracy: 0.8849 - val_loss: 7.4246 - val_accuracy: 0.2698
# Epoch 8/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.2532 - accuracy: 0.9147 - val_loss: 4.5166 - val_accuracy: 0.2698
# Epoch 9/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.1972 - accuracy: 0.9266 - val_loss: 10.9161 - val_accuracy: 0.2698
# Epoch 10/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.1658 - accuracy: 0.9484 - val_loss: 8.3090 - val_accuracy: 0.2698
# Epoch 11/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.1143 - accuracy: 0.9742 - val_loss: 7.0038 - val_accuracy: 0.2698
# Epoch 12/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0744 - accuracy: 0.9762 - val_loss: 4.4954 - val_accuracy: 0.2540
# Epoch 13/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0957 - accuracy: 0.9782 - val_loss: 6.3948 - val_accuracy: 0.2698
# Epoch 14/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0829 - accuracy: 0.9782 - val_loss: 7.9166 - val_accuracy: 0.2698
# Epoch 15/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.1065 - accuracy: 0.9722 - val_loss: 5.6453 - val_accuracy: 0.2698
# Epoch 16/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0752 - accuracy: 0.9782 - val_loss: 4.2371 - val_accuracy: 0.2857
# Epoch 17/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0715 - accuracy: 0.9861 - val_loss: 6.2283 - val_accuracy: 0.2619
# Epoch 18/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0573 - accuracy: 0.9901 - val_loss: 4.2551 - val_accuracy: 0.2937
# Epoch 19/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0564 - accuracy: 0.9802 - val_loss: 6.6968 - val_accuracy: 0.2778
# Epoch 20/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0405 - accuracy: 0.9940 - val_loss: 3.6440 - val_accuracy: 0.3571
# Epoch 21/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0395 - accuracy: 0.9921 - val_loss: 7.4008 - val_accuracy: 0.2619
# Epoch 22/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0643 - accuracy: 0.9881 - val_loss: 8.1364 - val_accuracy: 0.2619
# Epoch 23/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0288 - accuracy: 0.9940 - val_loss: 4.7586 - val_accuracy: 0.3254
# Epoch 24/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0466 - accuracy: 0.9881 - val_loss: 9.1055 - val_accuracy: 0.2698
# Epoch 25/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0497 - accuracy: 0.9901 - val_loss: 4.7545 - val_accuracy: 0.3333
# Epoch 26/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0396 - accuracy: 0.9921 - val_loss: 5.8401 - val_accuracy: 0.2937
# Epoch 27/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0517 - accuracy: 0.9901 - val_loss: 5.7996 - val_accuracy: 0.3095
# Epoch 28/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0504 - accuracy: 0.9861 - val_loss: 6.6774 - val_accuracy: 0.2698
# Epoch 29/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0311 - accuracy: 0.9960 - val_loss: 8.3569 - val_accuracy: 0.2698
# Epoch 30/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0327 - accuracy: 0.9901 - val_loss: 8.5227 - val_accuracy: 0.2778
# Epoch 31/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0114 - accuracy: 0.9980 - val_loss: 6.1578 - val_accuracy: 0.3175
# Epoch 32/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0281 - accuracy: 0.9921 - val_loss: 6.3959 - val_accuracy: 0.3254
# Epoch 33/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0308 - accuracy: 0.9881 - val_loss: 6.3568 - val_accuracy: 0.3095
# Epoch 34/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0223 - accuracy: 0.9921 - val_loss: 5.6750 - val_accuracy: 0.3333
# Epoch 35/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0256 - accuracy: 0.9921 - val_loss: 4.6843 - val_accuracy: 0.3810
# Epoch 36/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0221 - accuracy: 0.9921 - val_loss: 3.2373 - val_accuracy: 0.4921
# Epoch 37/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0387 - accuracy: 0.9881 - val_loss: 3.8187 - val_accuracy: 0.4286
# Epoch 38/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0284 - accuracy: 0.9901 - val_loss: 3.6081 - val_accuracy: 0.4444
# Epoch 39/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0584 - accuracy: 0.9921 - val_loss: 2.2474 - val_accuracy: 0.5238
# Epoch 40/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0249 - accuracy: 0.9960 - val_loss: 2.1317 - val_accuracy: 0.6190
# Epoch 41/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0197 - accuracy: 0.9940 - val_loss: 2.0743 - val_accuracy: 0.6349
# Epoch 42/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0435 - accuracy: 0.9881 - val_loss: 2.2238 - val_accuracy: 0.6825
# Epoch 43/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0337 - accuracy: 0.9921 - val_loss: 2.4320 - val_accuracy: 0.6349
# Epoch 44/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0540 - accuracy: 0.9861 - val_loss: 2.7405 - val_accuracy: 0.6190
# Epoch 45/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0598 - accuracy: 0.9802 - val_loss: 2.0913 - val_accuracy: 0.6825
# Epoch 46/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0677 - accuracy: 0.9762 - val_loss: 1.9271 - val_accuracy: 0.6508
# Epoch 47/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0629 - accuracy: 0.9861 - val_loss: 1.3345 - val_accuracy: 0.7143
# Epoch 48/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0563 - accuracy: 0.9742 - val_loss: 1.4997 - val_accuracy: 0.6825
# Epoch 49/80
# 16/16 [==============================] - 9s 544ms/step - loss: 0.0331 - accuracy: 0.9861 - val_loss: 1.2855 - val_accuracy: 0.7222
# Epoch 50/80
# 16/16 [==============================] - 9s 544ms/step - loss: 0.0539 - accuracy: 0.9841 - val_loss: 1.5161 - val_accuracy: 0.6825
# Epoch 51/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0482 - accuracy: 0.9881 - val_loss: 1.3997 - val_accuracy: 0.7063
# Epoch 52/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0309 - accuracy: 0.9881 - val_loss: 1.4121 - val_accuracy: 0.7063
# Epoch 53/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0613 - accuracy: 0.9802 - val_loss: 1.6264 - val_accuracy: 0.6746
# Epoch 54/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0608 - accuracy: 0.9762 - val_loss: 2.1841 - val_accuracy: 0.6984
# Epoch 55/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0669 - accuracy: 0.9841 - val_loss: 1.6936 - val_accuracy: 0.6984
# Epoch 56/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0629 - accuracy: 0.9861 - val_loss: 1.5014 - val_accuracy: 0.7222
# Epoch 57/80
# ...
# Epoch 59/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0319 - accuracy: 0.9960 - val_loss: 1.6423 - val_accuracy: 0.7302
# Epoch 60/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 1.5729 - val_accuracy: 0.7698
# Epoch 61/80
# 16/16 [==============================] - 9s 545ms/step - loss: 0.0173 - accuracy: 0.9960 - val_loss: 1.3635 - val_accuracy: 0.7619
# Epoch 62/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0074 - accuracy: 0.9960 - val_loss: 1.4039 - val_accuracy: 0.7619
# Epoch 63/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0133 - accuracy: 0.9940 - val_loss: 1.3838 - val_accuracy: 0.7619
# Epoch 64/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0235 - accuracy: 0.9980 - val_loss: 1.3606 - val_accuracy: 0.7222
# Epoch 65/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0105 - accuracy: 0.9980 - val_loss: 1.3437 - val_accuracy: 0.7143
# Epoch 66/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0287 - accuracy: 0.9921 - val_loss: 1.3450 - val_accuracy: 0.7063
# Epoch 67/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0185 - accuracy: 0.9960 - val_loss: 1.5698 - val_accuracy: 0.7460
# Epoch 68/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 1.4875 - val_accuracy: 0.7460
# Epoch 69/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0148 - accuracy: 0.9940 - val_loss: 1.4905 - val_accuracy: 0.7619
# Epoch 70/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0393 - accuracy: 0.9881 - val_loss: 1.4595 - val_accuracy: 0.7698
# Epoch 71/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0369 - accuracy: 0.9940 - val_loss: 1.4582 - val_accuracy: 0.7222
# Epoch 72/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0208 - accuracy: 0.9881 - val_loss: 1.5517 - val_accuracy: 0.7619
# Epoch 73/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0409 - accuracy: 0.9881 - val_loss: 1.4515 - val_accuracy: 0.7540
# Epoch 74/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0132 - accuracy: 0.9980 - val_loss: 1.8040 - val_accuracy: 0.6905
# Epoch 75/80
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0171 - accuracy: 0.9960 - val_loss: 1.7982 - val_accuracy: 0.6984
# Epoch 76/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0195 - accuracy: 0.9940 - val_loss: 1.6698 - val_accuracy: 0.7063
# Epoch 77/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0271 - accuracy: 0.9921 - val_loss: 1.6868 - val_accuracy: 0.7143
# Epoch 78/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0691 - accuracy: 0.9802 - val_loss: 1.7209 - val_accuracy: 0.6587
# Epoch 79/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.1146 - accuracy: 0.9663 - val_loss: 1.9967 - val_accuracy: 0.6587
# Epoch 80/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0510 - accuracy: 0.9802 - val_loss: 2.0016 - val_accuracy: 0.7063
# (126, 224, 224, 3)
# (126,)
# Acurracy: 0.706349
# F1: 0.675954
# Precision: 0.684817
# Recall: 0.679577
# ==========================================================================
# (504, 224, 224, 3)
# (504,)
# Epoch 1/80
# 16/16 [==============================] - 11s 568ms/step - loss: 5.2884 - accuracy: 0.4802 - val_loss: 1.4523 - val_accuracy: 0.5635
# Epoch 2/80
# 16/16 [==============================] - 9s 539ms/step - loss: 2.1216 - accuracy: 0.4881 - val_loss: 16.8249 - val_accuracy: 0.2698
# Epoch 3/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.9643 - accuracy: 0.6230 - val_loss: 10.4211 - val_accuracy: 0.2698
# Epoch 4/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.8050 - accuracy: 0.6885 - val_loss: 1.8821 - val_accuracy: 0.1667
# Epoch 5/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.7162 - accuracy: 0.7123 - val_loss: 1.8686 - val_accuracy: 0.2222
# Epoch 6/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.5384 - accuracy: 0.7857 - val_loss: 1.3119 - val_accuracy: 0.2381
# Epoch 7/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.4602 - accuracy: 0.8274 - val_loss: 2.4990 - val_accuracy: 0.2698
# Epoch 8/80
# 16/16 [==============================] - 9s 535ms/step - loss: 0.3756 - accuracy: 0.8512 - val_loss: 1.9523 - val_accuracy: 0.1905
# Epoch 9/80
# 16/16 [==============================] - 9s 536ms/step - loss: 0.2798 - accuracy: 0.9008 - val_loss: 1.5230 - val_accuracy: 0.2778
# Epoch 10/80
# 16/16 [==============================] - 9s 534ms/step - loss: 0.2458 - accuracy: 0.9167 - val_loss: 1.7757 - val_accuracy: 0.2063
# Epoch 11/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.2513 - accuracy: 0.9206 - val_loss: 1.9307 - val_accuracy: 0.1825
# Epoch 12/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.2189 - accuracy: 0.9306 - val_loss: 1.7561 - val_accuracy: 0.2143
# Epoch 13/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.1651 - accuracy: 0.9425 - val_loss: 1.4710 - val_accuracy: 0.3016
# Epoch 14/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.1910 - accuracy: 0.9306 - val_loss: 1.1308 - val_accuracy: 0.3889
# Epoch 15/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.1641 - accuracy: 0.9563 - val_loss: 1.4610 - val_accuracy: 0.3889
# Epoch 16/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.1210 - accuracy: 0.9583 - val_loss: 1.9169 - val_accuracy: 0.2302
# Epoch 17/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.1232 - accuracy: 0.9603 - val_loss: 1.2816 - val_accuracy: 0.5079
# Epoch 18/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.1580 - accuracy: 0.9583 - val_loss: 1.6439 - val_accuracy: 0.4206
# Epoch 19/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.1049 - accuracy: 0.9663 - val_loss: 1.8867 - val_accuracy: 0.4683
# Epoch 20/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.1227 - accuracy: 0.9563 - val_loss: 1.7859 - val_accuracy: 0.5873
# Epoch 21/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.1269 - accuracy: 0.9623 - val_loss: 2.4079 - val_accuracy: 0.4762
# Epoch 22/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.1270 - accuracy: 0.9583 - val_loss: 2.9381 - val_accuracy: 0.3810
# Epoch 23/80
# 16/16 [==============================] - 9s 536ms/step - loss: 0.0919 - accuracy: 0.9663 - val_loss: 2.4605 - val_accuracy: 0.5317
# Epoch 24/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.0831 - accuracy: 0.9742 - val_loss: 2.9391 - val_accuracy: 0.4603
# Epoch 25/80
# 16/16 [==============================] - 9s 536ms/step - loss: 0.0742 - accuracy: 0.9802 - val_loss: 2.7285 - val_accuracy: 0.5159
# Epoch 26/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.0436 - accuracy: 0.9881 - val_loss: 3.5413 - val_accuracy: 0.4444
# Epoch 27/80
# 16/16 [==============================] - 9s 536ms/step - loss: 0.0775 - accuracy: 0.9762 - val_loss: 3.9584 - val_accuracy: 0.3571
# Epoch 28/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.0496 - accuracy: 0.9841 - val_loss: 2.4366 - val_accuracy: 0.4762
# Epoch 29/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.0449 - accuracy: 0.9841 - val_loss: 2.7557 - val_accuracy: 0.4286
# Epoch 30/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.0529 - accuracy: 0.9841 - val_loss: 3.2553 - val_accuracy: 0.4127
# Epoch 31/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0485 - accuracy: 0.9802 - val_loss: 2.7113 - val_accuracy: 0.4921
# Epoch 32/80
# 16/16 [==============================] - 9s 536ms/step - loss: 0.0745 - accuracy: 0.9663 - val_loss: 2.5741 - val_accuracy: 0.4524
# Epoch 33/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.0812 - accuracy: 0.9762 - val_loss: 1.9527 - val_accuracy: 0.5079
# Epoch 34/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.0695 - accuracy: 0.9782 - val_loss: 3.4098 - val_accuracy: 0.3651
# Epoch 35/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0451 - accuracy: 0.9881 - val_loss: 2.9453 - val_accuracy: 0.4286
# Epoch 36/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.0834 - accuracy: 0.9742 - val_loss: 2.2940 - val_accuracy: 0.4762
# Epoch 37/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0336 - accuracy: 0.9881 - val_loss: 2.5052 - val_accuracy: 0.4365
# Epoch 38/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0312 - accuracy: 0.9881 - val_loss: 1.6867 - val_accuracy: 0.5397
# Epoch 39/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0575 - accuracy: 0.9841 - val_loss: 1.3904 - val_accuracy: 0.5635
# Epoch 40/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0706 - accuracy: 0.9762 - val_loss: 1.6372 - val_accuracy: 0.5635
# Epoch 41/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0423 - accuracy: 0.9861 - val_loss: 1.2715 - val_accuracy: 0.6825
# Epoch 42/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0415 - accuracy: 0.9821 - val_loss: 1.1958 - val_accuracy: 0.6825
# Epoch 43/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.1061 - accuracy: 0.9782 - val_loss: 1.0986 - val_accuracy: 0.6984
# Epoch 44/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0649 - accuracy: 0.9782 - val_loss: 1.6523 - val_accuracy: 0.5476
# Epoch 45/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0787 - accuracy: 0.9722 - val_loss: 1.7669 - val_accuracy: 0.6032
# Epoch 46/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.1063 - accuracy: 0.9603 - val_loss: 1.4237 - val_accuracy: 0.7302
# Epoch 47/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0786 - accuracy: 0.9841 - val_loss: 1.0697 - val_accuracy: 0.7381
# Epoch 48/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.0420 - accuracy: 0.9881 - val_loss: 0.9503 - val_accuracy: 0.7302
# Epoch 49/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0441 - accuracy: 0.9861 - val_loss: 1.0491 - val_accuracy: 0.7460
# Epoch 50/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.0399 - accuracy: 0.9881 - val_loss: 1.2140 - val_accuracy: 0.7302
# Epoch 51/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0353 - accuracy: 0.9881 - val_loss: 1.1095 - val_accuracy: 0.7302
# Epoch 52/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0395 - accuracy: 0.9901 - val_loss: 1.2685 - val_accuracy: 0.7302
# Epoch 53/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0510 - accuracy: 0.9841 - val_loss: 1.1811 - val_accuracy: 0.7460
# Epoch 54/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0506 - accuracy: 0.9841 - val_loss: 1.2723 - val_accuracy: 0.7619
# Epoch 55/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.0581 - accuracy: 0.9782 - val_loss: 1.3809 - val_accuracy: 0.7302
# Epoch 56/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0724 - accuracy: 0.9782 - val_loss: 1.3107 - val_accuracy: 0.7619
# Epoch 57/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0733 - accuracy: 0.9702 - val_loss: 1.4316 - val_accuracy: 0.7302
# Epoch 58/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0397 - accuracy: 0.9861 - val_loss: 1.4507 - val_accuracy: 0.7143
# Epoch 59/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0581 - accuracy: 0.9802 - val_loss: 1.1909 - val_accuracy: 0.7302
# Epoch 60/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.1106 - accuracy: 0.9683 - val_loss: 1.2593 - val_accuracy: 0.7381
# Epoch 61/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0738 - accuracy: 0.9722 - val_loss: 1.5098 - val_accuracy: 0.7143
# Epoch 62/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0787 - accuracy: 0.9802 - val_loss: 1.2161 - val_accuracy: 0.7698
# Epoch 63/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0561 - accuracy: 0.9861 - val_loss: 1.2518 - val_accuracy: 0.7698
# Epoch 64/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0493 - accuracy: 0.9841 - val_loss: 1.0736 - val_accuracy: 0.7619
# Epoch 65/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0324 - accuracy: 0.9861 - val_loss: 1.2875 - val_accuracy: 0.7302
# Epoch 66/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0340 - accuracy: 0.9881 - val_loss: 1.4881 - val_accuracy: 0.6825
# Epoch 67/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.1063 - accuracy: 0.9663 - val_loss: 1.4396 - val_accuracy: 0.7143
# Epoch 68/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.0778 - accuracy: 0.9722 - val_loss: 1.3254 - val_accuracy: 0.6984
# Epoch 69/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0526 - accuracy: 0.9782 - val_loss: 1.5142 - val_accuracy: 0.7222
# Epoch 70/80
# 16/16 [==============================] - 9s 537ms/step - loss: 0.0398 - accuracy: 0.9921 - val_loss: 1.4582 - val_accuracy: 0.7302
# Epoch 71/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.0464 - accuracy: 0.9861 - val_loss: 1.3431 - val_accuracy: 0.6984
# Epoch 72/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.0415 - accuracy: 0.9821 - val_loss: 1.2917 - val_accuracy: 0.7540
# Epoch 73/80
# 16/16 [==============================] - 9s 536ms/step - loss: 0.0307 - accuracy: 0.9881 - val_loss: 1.2531 - val_accuracy: 0.7619
# Epoch 74/80
# 16/16 [==============================] - 9s 538ms/step - loss: 0.0383 - accuracy: 0.9881 - val_loss: 1.1676 - val_accuracy: 0.7698
# Epoch 75/80
# 16/16 [==============================] - 9s 539ms/step - loss: 0.0786 - accuracy: 0.9683 - val_loss: 1.2733 - val_accuracy: 0.7540
# Epoch 76/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.1195 - accuracy: 0.9603 - val_loss: 1.5013 - val_accuracy: 0.6746
# Epoch 77/80
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0334 - accuracy: 0.9921 - val_loss: 1.3082 - val_accuracy: 0.6825
# Epoch 78/80
# 16/16 [==============================] - 9s 544ms/step - loss: 0.0327 - accuracy: 0.9881 - val_loss: 1.2145 - val_accuracy: 0.7381
# Epoch 79/80
# 16/16 [==============================] - 9s 540ms/step - loss: 0.0440 - accuracy: 0.9901 - val_loss: 1.1983 - val_accuracy: 0.7222
# Epoch 80/80
# 16/16 [==============================] - 9s 541ms/step - loss: 0.0451 - accuracy: 0.9841 - val_loss: 1.1664 - val_accuracy: 0.7937
# (126, 224, 224, 3)
# (126,)
# Acurracy: 0.793651
# F1: 0.748516
# Precision: 0.786514
# Recall: 0.725280
# ==========================================================================
# ===================================================================
# > Global accuracy: 0.7825396825396825 0.04335396915475447
# > Global F1_Score:  0.7485024310200031 0.04424833724857802
# > Global Precision: 0.7650673842428654 0.048458500464738555
# > Global Recall:  0.7440384194650972 0.04128778353011633
# ===================================================================
# Acuracia [0.8095238095238095, 0.8333333333333334, 0.7698412698412699, 0.7063492063492064, 0.7936507936507936]
# ===================================================================
# F1 Score [0.77584229390681, 0.8082313681868744, 0.7339688617659181, 0.6759535655058043, 0.7485160657346087]
# ===================================================================
# Precision [0.8051635223176036, 0.8135256695976336, 0.7353164731896075, 0.6848169191919191, 0.7865143369175627]
# ===================================================================
# Recall [0.7550149381135297, 0.8055199886185802, 0.7548001018589255, 0.6795772854596384, 0.7252797832748122]

# %% [markdown]
# # # **Model Test on Test Set**

# %% [markdown]
# Se quiser ver o desempenho do modelo no test set deve
# 1. Train o modelo em todo training set( sem usar K-fold cross validation dessa vez)
# 2. Testar o teu modelo no test set
# 3. O Desempenho do teu modelo deve estar dentro do intervalo de confia definido pelo K-fold

# %%
# model = tf.keras.applications.xception.Xception( weights=None,
#                                                 input_shape=(IMAGE_SIZE, IMAGE_SIZE,3), classes=3, classifier_activation='softmax')

# #Compilar modelo

# # model.summary()

# model.compile(optimizer=optimizer, loss=loss_function, metrics=['accuracy'])

# xcept = model.fit(imagens, labels,batch_size=batchsize, verbose=1,epochs=epoch)

# %%
# #Load Test data

# imgs_test, labs_test = load_data(test_data)
# print(imgs_test.shape)
# print(labs_test.shape)

# labs_predict = model.predict(imgs_test)
# labs_predict = np.argmax(labs_predict, axis=1)

# accuracy = metrics.accuracy_score(labs_test, labs_predict)
# f1 = metrics.f1_score(labs_test, labs_predict, average="macro")
# precision = metrics.precision_score(labs_test, labs_predict, average="macro")
# recall = metrics.recall_score(labs_test, labs_predict, average="macro")

# print('Acurracy: %f' % accuracy)
# print('F1: %f' % f1)
# print('Precision: %f' % precision)
# print('Recall: %f' % recall)
